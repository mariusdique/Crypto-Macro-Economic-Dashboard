# %%
import yfinance as yf
import matplotlib.pyplot as plt

sp500 = yf.download("^GSPC", start="1975-01-01", interval="1mo") #Every month

sp500 = sp500.reset_index()[["Date", "Close"]] # We move Date from the index to a column
sp500 = sp500.rename(columns={"Date": "date", "Close": "value"}) # Rename columns

print(sp500)


sp500.to_csv("SP500_data.csv")
# Out:
# C:\Users\Muhammad\AppData\Local\Temp\ipykernel_10596\3522695554.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500 = yf.download("^GSPC", start="1975-01-01", interval="1mo") #Every month
# [*********************100%***********************]  1 of 1 completed
# Price        date        value
# Ticker                   ^GSPC
# 0      1985-01-01   179.630005
# 1      1985-02-01   181.179993
# 2      1985-03-01   180.660004
# 3      1985-04-01   179.830002
# 4      1985-05-01   189.550003
# ..            ...          ...
# 483    2025-04-01  5569.060059
# 484    2025-05-01  5911.689941
# 485    2025-06-01  6204.950195
# 486    2025-07-01  6339.390137
# 487    2025-08-01  6460.259766
#
# [488 rows x 2 columns]

# %%
plt.figure(figsize=(10,5))
plt.plot(sp500["date"], sp500["value"], color="blue", label="S&P500 (Close)")

plt.title("S&P500 Index (Close)")
plt.xlabel("Date")
plt.ylabel("Index Level")
plt.legend()
plt.grid(True)
plt.show()
